# %%
import requests

headers = {
    "Authorization": "x96TGCf_Wjuh-DdIpkK9wbmV7cHG-MN18TvNLOXAcn3vLxwQ",
    "Accept": "application/json"
}

response = requests.get("https://api.sky.cirium.com/v1/flights/status/airline/TR/flight-number/134/departure-date/2026-04-7", headers=headers)
print(response.json())
# Out:
# {'request': {'airline': {'requestedCode': 'TR', 'fsCode': 'TR'}, 'flight': {'requested': '134', 'interpreted': '134'}, 'utc': {'interpreted': False}, 'url': 'https://api.sky.cirium.com/v1/flights/status/airline/TR/flight-number/134/departure-date/2026-04-7?extendedOptions=useHTTPErrors%2C', 'nonstopOnly': {'interpreted': False}, 'date': {'year': '2026', 'month': '04', 'day': '7', 'interpreted': '2026-04-07'}, 'extendedOptions': {'requested': 'useHTTPErrors,', 'interpreted': 'useHTTPErrors'}}, 'appendix': {'airlines': [{'fs': 'TR', 'iata': 'TR', 'icao': 'TGW', 'name': 'Scoot', 'active': True}, {'fs': 'SQ', 'iata': 'SQ', 'icao': 'SIA', 'name': 'Singapore Airlines', 'active': True}], 'airports': [{'fs': 'XIY', 'iata': 'XIY', 'icao': 'ZLXY', 'faa': '', 'name': "Xi'an Xianyang International Airport", 'street1': 'Airport Ave', 'city': 'Xian', 'cityCode': 'SIA', 'countryCode': 'CN', 'countryName': 'China', 'regionName': 'Asia', 'timeZoneRegionName': 'Asia/Shanghai', 'weatherZone': '', 'loca
# ...
